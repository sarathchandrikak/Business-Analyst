# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Overview of Subsetting in Pandas 📍 📍</h1></center>
#
#
#
# ---
#
# #### `TABLE OF CONTENTS`
#
# - What is an index?
# - How to subset first N rows based on their position index?
# - Can we change the index?
# - Will the index be always numeric?
# - How to subset the data based on a label of the index?
# - Can we reset the index?
# - How to subset the data based on a value of a column?
#
# ---
#
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.

# %%
# import the pandas library
import pandas as pd

# %%
# read the big mart sales data
data = pd.read_csv('datasets/big_mart_sales.csv')

# %% [markdown]
# #### `WHAT IS INDEX?`
#
# ![](index.png)
#
# -  You can see the index object by `DataFrame.index`.

# %%
# index of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# ***So, In this case, we have the numeric index value start from the 0 and ends at 8523.***

# %%
# no. of rows and columns in the data
data.shape
# Out:
# (8523, 12)

# %%
# column index
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# #### `HOW TO SUBSET FIRST 'N' ROWS BASED ON THEIR POSITION INDEX?`

# %%
# view the top rows of the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ---
#
# #### `CAN WE CHANGE THE INDEX?`
#
# ---
#
# ***The answer is `Yes`. We can change the index. Let's see how?***
#
# ---

# %% [markdown]
# #### Create a random list of 8523 numbers and set it as the index
# ---

# %%
# create random list
import random
random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# [1838,
#  2170,
#  3008,
#  798,
#  3654,
#  7313,
#  2419,
#  3074,
#  7024,
#  4957,
#  3632,
#  8012,
#  6423,
#  4128,
#  6985,
#  5153,
#  2775,
#  7336,
#  577,
#  7291,
#  2513,
#  2716,
#  1284,
#  3328,
#  6545,
#  6418,
#  4062,
#  6351,
#  219,
#  4555,
#  6338,
#  3338,
#  7267,
#  7325,
#  5539,
#  4147,
#  5466,
#  2609,
#  4743,
#  3341,
#  7483,
#  2092,
#  2039,
#  6539,
#  5189,
#  6412,
#  5664,
#  5794,
#  889,
#  7214,
#  3610,
#  8460,
#  4034,
#  4893,
#  3586,
#  2662,
#  1333,
#  4619,
#  2199,
#  4018,
#  7529,
#  6945,
#  5683,
#  3993,
#  2805,
#  5033,
#  3664,
#  5239,
#  3242,
#  654,
#  5091,
#  5057,
#  8508,
#  6934,
#  8396,
#  8373,
#  18,
#  3005,
#  6487,
#  6607,
#  741,
#  588,
#  6083,
#  1943,
#  7557,
#  6620,
#  8320,
#  4231,
#  668,
#  2195,
#  8159,
#  6508,
#  7047,
#  3877,
#  2782,
#  1957,
#  3612,
#  1670,
#  4522,
#  8515,
#  5362,
#  3962,
#  6900,
#  3862,
#  2011,
#  7978,
#  7401,
#  1772,
#  2991,
#  2255,
#  6630,
#  4053,
#  8005,
#  6754,
#  3859,
#  516,
#  7716,
#  566,
#  1942,
#  458,
#  4387,
#  3827,
#  3936,
#  621,
#  4934,
#  2989,
#  8166,
#  4535,
#  2440,
#  5522,
#  8276,
#  4086,
#  1906,
#  5955,
#  2797,
#  7851,
#  6238,
#  3858,
#  6032,
#  3155,
#  234,
#  2944,
#  3329,
#  8303,
#  1434,
#  2815,
#  3730,
#  7656,
#  4860,
#  4406,
#  8099,
#  1144,
#  4675,
#  4739,
#  3441,
#  5918,
#  8246,
#  2613,
#  4040,
#  1762,
#  4119,
#  382,
#  4976,
#  208,
#  2509,
#  1633,
#  8061,
#  2403,
#  5576,
#  1661,
#  2155,
#  2031,
#  2858,
#  1465,
#  1635,
#  1644,
#  4959,
#  2629,
#  6222,
#  3985,
#  1562,
#  5980,
#  5877,
#  6125,
#  6833,
#  1515,
#  5676,
#  6838,
#  5600,
#  1508,
#  6481,
#  5473,
#  4158,
#  4384,
#  2481,
#  3808,
#  3368,
#  6889,
#  5981,
#  2816,
#  5773,
#  2016,
#  168,
#  3486,
#  84,
#  4895,
#  7005,
#  321,
#  5034,
#  42,
#  467,
#  6081,
#  569,
#  8467,
#  3734,
#  5699,
#  1227,
#  1165,
#  7663,
#  7741,
#  6948,
#  4529,
#  1124,
#  7939,
#  1848,
#  5405,
#  611,
#  263,
#  5970,
#  2495,
#  2876,
#  6814,
#  2541,
#  685,
#  4574,
#  7198,
#  1389,
#  4910,
#  6660,
#  22,
#  8242,
#  7627,
#  1541,
#  4406,
#  8201,
#  6031,
#  7448,
#  7487,
#  7443,
#  2214,
#  3631,
#  4689,
#  2801,
#  7431,
#  4976,
#  5600,
#  2780,
#  7174,
#  6105,
#  413,
#  4835,
#  4008,
#  3912,
#  3250,
#  5507,
#  416,
#  3629,
#  1797,
#  6452,
#  2040,
#  3348,
#  4460,
#  6780,
#  6144,
#  2050,
#  192,
#  6269,
#  227,
#  2867,
#  3646,
#  6138,
#  5527,
#  139,
#  6834,
#  3753,
#  5958,
#  7991,
#  6007,
#  2087,
#  7538,
#  1821,
#  6834,
#  7998,
#  4205,
#  331,
#  5255,
#  3493,
#  1270,
#  3666,
#  7856,
#  6623,
#  1947,
#  4570,
#  6277,
#  5599,
#  3147,
#  2105,
#  4426,
#  5181,
#  4672,
#  82,
#  6303,
#  3119,
#  4082,
#  7623,
#  3607,
#  5963,
#  7809,
#  4843,
#  3901,
#  2140,
#  6582,
#  7521,
#  7201,
#  7141,
#  5160,
#  3271,
#  2189,
#  3772,
#  6630,
#  3277,
#  5825,
#  1935,
#  5945,
#  2287,
#  8172,
#  2391,
#  7470,
#  5175,
#  4332,
#  5177,
#  6556,
#  8144,
#  2037,
#  4229,
#  7382,
#  6015,
#  19,
#  7513,
#  7269,
#  2008,
#  7361,
#  6435,
#  524,
#  6472,
#  1363,
#  6046,
#  38,
#  5989,
#  153,
#  7722,
#  5276,
#  3919,
#  696,
#  696,
#  6325,
#  7754,
#  6935,
#  3305,
#  8113,
#  5383,
#  3779,
#  6919,
#  3874,
#  7612,
#  4966,
#  4229,
#  8171,
#  1658,
#  2123,
#  134,
#  7133,
#  6505,
#  5157,
#  5481,
#  1259,
#  3497,
#  5956,
#  8434,
#  5872,
#  7976,
#  4841,
#  5251,
#  8393,
#  6052,
#  4553,
#  5342,
#  3924,
#  6019,
#  7569,
#  3103,
#  1278,
#  2614,
#  7229,
#  1585,
#  4446,
#  4663,
#  5523,
#  6104,
#  7467,
#  7415,
#  969,
#  907,
#  229,
#  3282,
#  4733,
#  281,
#  7758,
#  6765,
#  8160,
#  2075,
#  917,
#  392,
#  5312,
#  3860,
#  2347,
#  1766,
#  3322,
#  5517,
#  7209,
#  2802,
#  4374,
#  5278,
#  8447,
#  5577,
#  2181,
#  6319,
#  1584,
#  5944,
#  3714,
#  866,
#  3756,
#  2317,
#  7226,
#  5337,
#  7478,
#  3700,
#  181,
#  3128,
#  4127,
#  6841,
#  7631,
#  887,
#  2622,
#  6183,
#  1230,
#  7757,
#  513,
#  4421,
#  2,
#  4644,
#  5100,
#  8485,
#  1609,
#  5632,
#  974,
#  2305,
#  3796,
#  538,
#  3175,
#  3392,
#  6873,
#  3280,
#  94,
#  4957,
#  7484,
#  6851,
#  6650,
#  4867,
#  2034,
#  168,
#  3023,
#  4622,
#  5595,
#  733,
#  8480,
#  1157,
#  4098,
#  3151,
#  3888,
#  6396,
#  2471,
#  6861,
#  5772,
#  6994,
#  6207,
#  4715,
#  2975,
#  4963,
#  4268,
#  1910,
#  3483,
#  5573,
#  2708,
#  904,
#  4048,
#  7145,
#  587,
#  6531,
#  7275,
#  2562,
#  7757,
#  2549,
#  912,
#  7027,
#  2054,
#  3237,
#  4905,
#  3020,
#  3706,
#  4429,
#  549,
#  245,
#  1811,
#  951,
#  4093,
#  8475,
#  1688,
#  6432,
#  8137,
#  6414,
#  307,
#  5778,
#  492,
#  6869,
#  8006,
#  5673,
#  2769,
#  502,
#  5677,
#  170,
#  5150,
#  739,
#  7972,
#  5724,
#  3358,
#  8168,
#  3574,
#  2724,
#  1366,
#  2163,
#  5052,
#  5588,
#  5878,
#  6203,
#  1797,
#  6059,
#  8421,
#  5228,
#  2054,
#  2722,
#  1506,
#  6157,
#  976,
#  7873,
#  7798,
#  531,
#  2508,
#  5857,
#  5483,
#  8430,
#  1513,
#  7342,
#  8005,
#  7011,
#  6941,
#  3411,
#  6881,
#  4540,
#  5364,
#  6816,
#  5442,
#  424,
#  5581,
#  7623,
#  4452,
#  1144,
#  8523,
#  4510,
#  3344,
#  5785,
#  174,
#  4749,
#  6213,
#  8030,
#  1107,
#  1000,
#  2410,
#  5021,
#  1971,
#  3879,
#  5920,
#  5159,
#  2018,
#  200,
#  2280,
#  7182,
#  6449,
#  8124,
#  5524,
#  2019,
#  2681,
#  5569,
#  3570,
#  286,
#  4743,
#  6686,
#  718,
#  961,
#  3,
#  3687,
#  1037,
#  4036,
#  5207,
#  6761,
#  7897,
#  6828,
#  201,
#  7542,
#  5085,
#  5103,
#  2952,
#  6581,
#  1418,
#  8117,
#  4168,
#  2418,
#  6665,
#  6918,
#  3312,
#  7139,
#  7908,
#  461,
#  5539,
#  2947,
#  1345,
#  7393,
#  5548,
#  4684,
#  5025,
#  1686,
#  998,
#  2414,
#  708,
#  1696,
#  6375,
#  6365,
#  5982,
#  7122,
#  3656,
#  729,
#  6255,
#  4248,
#  5307,
#  1265,
#  6774,
#  755,
#  8309,
#  1776,
#  3400,
#  4382,
#  5837,
#  3520,
#  1042,
#  5641,
#  5072,
#  5367,
#  5436,
#  5324,
#  1288,
#  1108,
#  4631,
#  4012,
#  2691,
#  4219,
#  7078,
#  1547,
#  2946,
#  7486,
#  7669,
#  7436,
#  5391,
#  1913,
#  4683,
#  680,
#  3711,
#  8170,
#  874,
#  7327,
#  2651,
#  6232,
#  8385,
#  922,
#  195,
#  989,
#  3284,
#  4154,
#  3795,
#  4787,
#  5607,
#  3223,
#  2266,
#  1566,
#  2080,
#  509,
#  3066,
#  70,
#  5785,
#  6126,
#  2655,
#  2422,
#  6705,
#  7710,
#  3577,
#  1374,
#  5399,
#  5886,
#  1054,
#  3804,
#  2250,
#  1151,
#  747,
#  3353,
#  75,
#  8383,
#  1830,
#  4196,
#  8471,
#  5901,
#  200,
#  3300,
#  5600,
#  5606,
#  4549,
#  299,
#  2746,
#  5514,
#  8302,
#  7435,
#  1400,
#  56,
#  2789,
#  4039,
#  6218,
#  5,
#  1053,
#  5156,
#  8155,
#  2352,
#  2334,
#  2638,
#  7293,
#  6523,
#  1659,
#  1737,
#  3981,
#  4195,
#  2807,
#  1106,
#  3076,
#  3295,
#  7146,
#  1533,
#  7939,
#  4215,
#  2017,
#  6788,
#  506,
#  1812,
#  5675,
#  8279,
#  1157,
#  2202,
#  7761,
#  256,
#  7311,
#  428,
#  286,
#  3650,
#  7132,
#  5123,
#  8406,
#  3260,
#  3528,
#  6843,
#  2198,
#  1479,
#  3364,
#  3864,
#  2587,
#  4616,
#  416,
#  7167,
#  5573,
#  6291,
#  3259,
#  3617,
#  235,
#  4100,
#  1681,
#  3287,
#  8377,
#  6316,
#  7406,
#  1809,
#  8169,
#  276,
#  803,
#  2204,
#  3043,
#  2180,
#  2041,
#  6552,
#  2672,
#  3111,
#  5977,
#  7344,
#  3695,
#  273,
#  6273,
#  3601,
#  8473,
#  1087,
#  7832,
#  3018,
#  4540,
#  8060,
#  2080,
#  5857,
#  3063,
#  2586,
#  1809,
#  1474,
#  4936,
#  3665,
#  4975,
#  7757,
#  5970,
#  5501,
#  5037,
#  3168,
#  7846,
#  6092,
#  1307,
#  2636,
#  5173,
#  7672,
#  7815,
#  4431,
#  1908,
#  94,
#  2328,
#  6878,
#  841,
#  3672,
#  7789,
#  6878,
#  7399,
#  5714,
#  3856,
#  7861,
#  257,
#  4039,
#  1114,
#  3160,
#  7930,
#  1609,
#  3013,
#  4656,
#  152,
#  5741,
#  1159,
#  2924,
#  978,
#  951,
#  3857,
#  560,
#  5082,
#  797,
#  4003,
#  5679,
#  7430,
#  5670,
#  6910,
#  2170,
#  1108,
#  2828,
#  63,
#  3233,
#  6169,
#  2240,
#  2748,
#  1257,
#  3761,
#  7699,
#  4366,
#  6275,
#  8467,
#  2607,
#  7163,
#  4692,
#  1119,
#  3306,
#  1720,
#  8395,
#  3433,
#  7936,
#  7302,
#  2142,
#  2987,
#  5462,
#  2201,
#  5881,
#  2116,
#  5843,
#  4244,
#  4941,
#  4370,
#  4347,
#  7518,
#  4180,
#  2220,
#  1198,
#  2448,
#  8069,
#  329,
#  5985,
#  5030,
#  3572,
#  5502,
#  3736,
#  7058,
#  7328,
#  219,
#  1763,
#  5189,
#  7020,
#  1461,
#  5709,
#  4712,
#  385,
#  2516,
#  1813,
#  8100,
#  2540,
#  3989,
#  1179,
#  1268,
#  3134,
#  8457,
#  2106,
#  7060,
#  6365,
#  5203,
#  4467,
#  5679,
#  2889,
#  7297,
#  6890,
#  4664,
#  5005,
#  552,
#  6424,
#  1643,
#  5525,
#  4767,
#  5009,
#  4513,
#  6731,
#  4101,
#  788,
#  297,
#  8278,
#  1928,
#  2166,
#  5726,
#  3805,
#  183,
#  4208,
#  5451,
#  882,
#  7874,
#  881,
#  3952,
#  719,
#  4632,
#  2859,
#  7695,
#  2359,
#  5510,
#  ...]

# %%
# set the index
data.index = random_list

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1838           FDA15         9.30          Low Fat         0.016047
# 2170           DRC01         5.92          Regular         0.019278
# 3008           FDN15        17.50          Low Fat         0.016760
# 798            FDX07        19.20          Regular         0.000000
# 3654           NCD19         8.93          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1838                  Dairy  249.8092            OUT049
# 2170            Soft Drinks   48.2692            OUT018
# 3008                   Meat  141.6180            OUT049
# 798   Fruits and Vegetables  182.0950            OUT010
# 3654              Household   53.8614            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1838                       1999      Medium               Tier 1
# 2170                       2009      Medium               Tier 3
# 3008                       1999      Medium               Tier 1
# 798                        1998         NaN               Tier 3
# 3654                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 1838  Supermarket Type1          3735.1380
# 2170  Supermarket Type2           443.4228
# 3008  Supermarket Type1          2097.2700
# 798       Grocery Store           732.3800
# 3654  Supermarket Type1           994.7052

# %% [markdown]
# ***Set another column of the dataframe as the index. We will use the set_index function. You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html'***
#
# ---

# %%
# 1. change the index of the dataframe
# 2. drop=True is used to drop the column that's set as index
# 3. inplace=True is used to make changes in the original dataframe
# data = pd.read_csv('datasets/big_mart_sales.csv')

data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)

# %%
# example of a label based index
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
#                           Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Outlet_Establishment_Year
# 1999                                 OUT049      Medium               Tier 1
# 2009                                 OUT018      Medium               Tier 3
# 1999                                 OUT049      Medium               Tier 1
# 1998                                 OUT010         NaN               Tier 3
# 1987                                 OUT013        High               Tier 3
#
#                                  Outlet_Type  Item_Outlet_Sales
# Outlet_Establishment_Year
# 1999                       Supermarket Type1          3735.1380
# 2009                       Supermarket Type2           443.4228
# 1999                       Supermarket Type1          2097.2700
# 1998                           Grocery Store           732.3800
# 1987                       Supermarket Type1           994.7052

# %%
data.index
# Out:
# Int64Index([1999, 2009, 1999, 1998, 1987, 2009, 1987, 1985, 2002, 2007,
#             ...
#             2004, 2002, 2009, 2009, 1997, 1987, 2002, 2004, 2009, 1997],
#            dtype='int64', name='Outlet_Establishment_Year', length=8523)

# %% [markdown]
# ---
#
# ### `WILL THE INDEX BE ALWAYS NUMERIC?`
#
# ---
#
#
# ***No, We can also have categorical variables as the index of a dataframe.***
#
# ---

# %%
# reset the index
data.set_index('Item_Identifier', drop= True, inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
#                  index  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                0         9.30          Low Fat         0.016047
# DRC01                1         5.92          Regular         0.019278
# FDN15                2        17.50          Low Fat         0.016760
# FDX07                3        19.20          Regular         0.000000
# NCD19                4         8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# DRC01                Medium               Tier 3  Supermarket Type2
# FDN15                Medium               Tier 1  Supermarket Type1
# FDX07                   NaN               Tier 3      Grocery Store
# NCD19                  High               Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# DRC01                     443.4228
# FDN15                    2097.2700
# FDX07                     732.3800
# NCD19                     994.7052

# %%
# index of the data
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %% [markdown]
# ---
#
# #### `HOW TO SUBSET THE DATA BASED ON THE LABEL OF THE INDEX?`
#
# - We can subset the data based on the label of the index using the loc function.
# ---

# %%
data.loc['FDA15']
# Out:
#                  index  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                0          9.3          Low Fat         0.016047
# FDA15              831          9.3          Low Fat         0.016055
# FDA15             2599          9.3          Low Fat         0.016019
# FDA15             2643          9.3          Low Fat         0.016088
# FDA15             4874          9.3          Low Fat         0.026818
# FDA15             5413          9.3          Low Fat         0.016009
# FDA15             6696          NaN          Low Fat         0.015945
# FDA15             7543          9.3               LF         0.016113
#
#                 Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# Item_Identifier
# FDA15               Dairy  249.8092            OUT049      Medium
# FDA15               Dairy  250.2092            OUT045         NaN
# FDA15               Dairy  248.5092            OUT035       Small
# FDA15               Dairy  249.6092            OUT018      Medium
# FDA15               Dairy  248.9092            OUT010         NaN
# FDA15               Dairy  250.6092            OUT013        High
# FDA15               Dairy  249.5092            OUT027      Medium
# FDA15               Dairy  248.8092            OUT017         NaN
#
#                 Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15                         Tier 1  Supermarket Type1          3735.1380
# FDA15                         Tier 2  Supermarket Type1          5976.2208
# FDA15                         Tier 2  Supermarket Type1          6474.2392
# FDA15                         Tier 3  Supermarket Type2          5976.2208
# FDA15                         Tier 3      Grocery Store           498.0184
# FDA15                         Tier 3  Supermarket Type1          6474.2392
# FDA15                         Tier 3  Supermarket Type3          6474.2392
# FDA15                         Tier 2  Supermarket Type1          5976.2208

# %% [markdown]
# ***What if we want to change the index back to positional?***
#
# ---
#
# #### `CAN WE RESET THE INDEX?`
#
# ***Yes, we can reset the index. Let's see how? We will use the reset_index function. You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html***
#
# ---

# %%
# reset the index
data.reset_index(inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
#    index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
# 2      2           FDN15        17.50          Low Fat         0.016760
# 3      3           FDX07        19.20          Regular         0.000000
# 4      4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                  Dairy  249.8092            OUT049      Medium
# 1            Soft Drinks   48.2692            OUT018      Medium
# 2                   Meat  141.6180            OUT049      Medium
# 3  Fruits and Vegetables  182.0950            OUT010         NaN
# 4              Household   53.8614            OUT013        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052

# %% [markdown]
# #### `HOW TO SUBSET THE DATA BASED ON A VALUE OF A COLUMN?`
#
# ---

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#       index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 11       11           FDA03       18.500          Regular         0.045464
# 19       19           FDU02       13.350          Low Fat         0.102492
# 28       28           FDE51        5.925          Regular         0.161467
# 30       30           FDV38       19.250          Low Fat         0.170349
# ...     ...             ...          ...              ...              ...
# 8424   8424           FDC39        7.405          Low Fat         0.159165
# 8447   8447           FDS26       20.350          Low Fat         0.089975
# 8448   8448           FDV50       14.300          Low Fat         0.123071
# 8457   8457           FDY50        5.800          Low Fat         0.130931
# 8512   8512           FDR26       20.700          Low Fat         0.042801
#
#      Item_Type  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# 0        Dairy  249.8092            OUT049      Medium               Tier 1
# 11       Dairy  144.1102            OUT046       Small               Tier 1
# 19       Dairy  230.5352            OUT035       Small               Tier 2
# 28       Dairy   45.5086            OUT010         NaN               Tier 3
# 30       Dairy   55.7956            OUT010         NaN               Tier 3
# ...        ...       ...               ...         ...                  ...
# 8424     Dairy  207.1296            OUT035       Small               Tier 2
# 8447     Dairy  261.6594            OUT017         NaN               Tier 2
# 8448     Dairy  121.1730            OUT018      Medium               Tier 3
# 8457     Dairy   89.9172            OUT035       Small               Tier 2
# 8512     Dairy  178.3028            OUT013        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 11    Supermarket Type1          2187.1530
# 19    Supermarket Type1          2748.4224
# 28        Grocery Store           178.4344
# 30        Grocery Store           163.7868
# ...                 ...                ...
# 8424  Supermarket Type1          3739.1328
# 8447  Supermarket Type1          7588.1226
# 8448  Supermarket Type2          2093.9410
# 8457  Supermarket Type1          1516.6924
# 8512  Supermarket Type1          2479.4392
#
# [682 rows x 12 columns]

# %% [markdown]
# ----
#
# #### `WE WILL SEE HOW TO SUBSET THE DATA BASED ON POSITION, LABEL AND VALUES IN DETAIL`
#
# ---
